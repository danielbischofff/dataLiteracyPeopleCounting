# %%
import pandas as pd
import pandas as pd
from scapy.all import rdpcap
from tueplots import bundles
from tueplots.constants.color import rgb
from matplotlib.colors import LinearSegmentedColormap

# %%
# load Data as csv
csvData = pd.read_csv('/Users/danielbischoff/Documents/Privat/ArbeitBeruf/UniTuebingen/DataLiteracy/dataLiteracyPeopleCounting/data/runs_thursday_00001_20240111110104TestData.csv')

# %%
# Plot bar graph of number of messages per minuteload 
csvData['Time'] = csvData['Time'].str.replace(r':\d+\.\d+', '', regex=True)
csvData['Time'].value_counts().sort_index().plot(kind='bar', color=rgb.tue_blue)
# Out:
# <Axes: xlabel='Time'>
