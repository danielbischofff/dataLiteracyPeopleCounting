# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sz
import pandas as pd
import pandas as pd
from scapy.all import rdpcap
from tueplots import bundles
from tueplots.constants.color import rgb
from matplotlib.colors import LinearSegmentedColormap
# Out:
# WARNING: Wireshark is installed, but cannot read manuf !

# %%
df=pd.read_csv(r"C:\Users\Sarthak\Desktop\dataliteracy_project\cleaned\Monday08012024.csv")
df
# Out:
#           frame.number                                         frame.time  \
# 0                    1  Jan  8, 2024 10:59:03.696487000 W. Europe Stan...
# 1                    2  Jan  8, 2024 10:59:03.705183000 W. Europe Stan...
# 2                    3  Jan  8, 2024 10:59:03.705281000 W. Europe Stan...
# 3                    4  Jan  8, 2024 10:59:03.705314000 W. Europe Stan...
# 4                    5  Jan  8, 2024 10:59:03.705341000 W. Europe Stan...
# ...                ...                                                ...
# 13870839        749929  Jan  8, 2024 14:09:05.331612000 W. Europe Stan...
# 13870840        749930  Jan  8, 2024 14:09:05.346703000 W. Europe Stan...
# 13870841        749931  Jan  8, 2024 14:09:05.346759000 W. Europe Stan...
# 13870842        749932  Jan  8, 2024 14:09:05.364913000 W. Europe Stan...
# 13870843        749933  Jan  8, 2024 14:09:05.411231000 W. Europe Stan...
#
#                     wlan.sa            wlan.da _ws.col.protocol  frame.len  \
# 0         00:f6:63:81:c8:6e  ff:ff:ff:ff:ff:ff           802.11        286
# 1                       NaN                NaN           802.11         35
# 2                       NaN                NaN           802.11         29
# 3                       NaN                NaN           802.11         36
# 4                       NaN                NaN           802.11         47
# ...                     ...                ...              ...        ...
# 13870839                NaN                NaN           802.11         29
# 13870840  aa:9f:59:02:dd:67  00:f6:63:81:c8:6f           802.11         43
# 13870841                NaN                NaN           802.11         29
# 13870842  00:f6:63:81:c8:6e  ff:ff:ff:ff:ff:ff           802.11        294
# 13870843                NaN                NaN           802.11         39
#
#           ip.src  ip.dst  _ws.col.Protocol  _ws.col.Info
# 0            NaN     NaN               NaN           NaN
# 1            NaN     NaN               NaN           NaN
# 2            NaN     NaN               NaN           NaN
# 3            NaN     NaN               NaN           NaN
# 4            NaN     NaN               NaN           NaN
# ...          ...     ...               ...           ...
# 13870839     NaN     NaN               NaN           NaN
# 13870840     NaN     NaN               NaN           NaN
# 13870841     NaN     NaN               NaN           NaN
# 13870842     NaN     NaN               NaN           NaN
# 13870843     NaN     NaN               NaN           NaN
#
# [13870844 rows x 10 columns]

# %%
df["frame.time"] = df["frame.time"].str.replace(r':\d+\.\d+', '', regex=True)
df["frame.time"].value_counts().sort_index().plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['date-time'] = pd.to_datetime(df['frame.time'].str.replace('W. Europe Standard Time', 'CET'), format='%b %d, %Y %H:%M %Z')
df['hour:minute'] = df['date-time'].dt.strftime('%H:%M')
df
# Out:
#           frame.number                                  frame.time  \
# 0                    1  Jan  8, 2024 10:59 W. Europe Standard Time
# 1                    2  Jan  8, 2024 10:59 W. Europe Standard Time
# 2                    3  Jan  8, 2024 10:59 W. Europe Standard Time
# 3                    4  Jan  8, 2024 10:59 W. Europe Standard Time
# 4                    5  Jan  8, 2024 10:59 W. Europe Standard Time
# ...                ...                                         ...
# 13870839        749929  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870840        749930  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870841        749931  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870842        749932  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870843        749933  Jan  8, 2024 14:09 W. Europe Standard Time
#
#                     wlan.sa            wlan.da _ws.col.protocol  frame.len  \
# 0         00:f6:63:81:c8:6e  ff:ff:ff:ff:ff:ff           802.11        286
# 1                       NaN                NaN           802.11         35
# 2                       NaN                NaN           802.11         29
# 3                       NaN                NaN           802.11         36
# 4                       NaN                NaN           802.11         47
# ...                     ...                ...              ...        ...
# 13870839                NaN                NaN           802.11         29
# 13870840  aa:9f:59:02:dd:67  00:f6:63:81:c8:6f           802.11         43
# 13870841                NaN                NaN           802.11         29
# 13870842  00:f6:63:81:c8:6e  ff:ff:ff:ff:ff:ff           802.11        294
# 13870843                NaN                NaN           802.11         39
#
#           ip.src  ip.dst  _ws.col.Protocol  _ws.col.Info  \
# 0            NaN     NaN               NaN           NaN
# 1            NaN     NaN               NaN           NaN
# 2            NaN     NaN               NaN           NaN
# 3            NaN     NaN               NaN           NaN
# 4            NaN     NaN               NaN           NaN
# ...          ...     ...               ...           ...
# 13870839     NaN     NaN               NaN           NaN
# 13870840     NaN     NaN               NaN           NaN
# 13870841     NaN     NaN               NaN           NaN
# 13870842     NaN     NaN               NaN           NaN
# 13870843     NaN     NaN               NaN           NaN
#
#                          date-time hour:minute
# 0        2024-01-08 10:59:00+01:00       10:59
# 1        2024-01-08 10:59:00+01:00       10:59
# 2        2024-01-08 10:59:00+01:00       10:59
# 3        2024-01-08 10:59:00+01:00       10:59
# 4        2024-01-08 10:59:00+01:00       10:59
# ...                            ...         ...
# 13870839 2024-01-08 14:09:00+01:00       14:09
# 13870840 2024-01-08 14:09:00+01:00       14:09
# 13870841 2024-01-08 14:09:00+01:00       14:09
# 13870842 2024-01-08 14:09:00+01:00       14:09
# 13870843 2024-01-08 14:09:00+01:00       14:09
#
# [13870844 rows x 12 columns]

# %%
per_min=pd.DataFrame(df["hour:minute"].value_counts().sort_index())
plt.plot(per_min['count'], marker='o')
plt.xlabel('Time (hour:minute)')
plt.ylabel('Count')
plt.title('Count vs Time')
sum(per_min['count'])/532
# Out:
# 26073.015037593985

# %%
df_first = df.drop_duplicates(subset='wlan.sa', keep='first')
df_first.tail()
# Out:
#           frame.number                                  frame.time  \
# 13870643        749733  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870735        749825  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870762        749852  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870814        749904  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870826        749916  Jan  8, 2024 14:09 W. Europe Standard Time
#
#                     wlan.sa            wlan.da _ws.col.protocol  frame.len  \
# 13870643  f0:aa:a4:ab:b7:6b                NaN           802.11         42
# 13870735  8b:f6:b3:57:2c:6b  a1:73:42:f0:a4:51           802.11       3092
# 13870762  b2:8c:ba:4b:2c:b2  86:e6:7c:36:b5:56           802.11        261
# 13870814  63:c0:75:38:db:30  78:4f:36:8d:e9:fd           802.11       2279
# 13870826  e7:a3:aa:d4:fd:9a  c0:98:26:52:c3:93           802.11        261
#
#           ip.src  ip.dst  _ws.col.Protocol  _ws.col.Info  \
# 13870643     NaN     NaN               NaN           NaN
# 13870735     NaN     NaN               NaN           NaN
# 13870762     NaN     NaN               NaN           NaN
# 13870814     NaN     NaN               NaN           NaN
# 13870826     NaN     NaN               NaN           NaN
#
#                          date-time hour:minute
# 13870643 2024-01-08 14:09:00+01:00       14:09
# 13870735 2024-01-08 14:09:00+01:00       14:09
# 13870762 2024-01-08 14:09:00+01:00       14:09
# 13870814 2024-01-08 14:09:00+01:00       14:09
# 13870826 2024-01-08 14:09:00+01:00       14:09

# %%
per_min_new=pd.DataFrame(df_first["hour:minute"].value_counts().sort_index())
plt.plot((per_min_new['count']/532), marker='o')
plt.xlabel('Time (hour:minute)')
plt.ylabel('Count')
plt.title('first seen Count vs Time')
# Out:
# Text(0.5, 1.0, 'first seen Count vs Time')

# %%
sum(per_min_new['count'])/532
# Out:
# 990.4887218045113

# %%
new_per5min = pd.DataFrame({'hour:minute':per_min_new.index.tolist(),'count': per_min_new["count"]})
new_per5min['hour:minute'] = pd.to_datetime(new_per5min['hour:minute'], format=None)
new_per5min.set_index('hour:minute', inplace=True)
new_per5min_new = new_per5min.resample('2T').sum()
new_per5min_new
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_25768\136048879.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_per5min['hour:minute'] = pd.to_datetime(new_per5min['hour:minute'], format=None)
#                      count
# hour:minute
# 2024-01-13 10:58:00    489
# 2024-01-13 11:00:00    502
# 2024-01-13 11:02:00    203
# 2024-01-13 11:04:00    283
# 2024-01-13 11:06:00    172
# ...                    ...
# 2024-01-13 14:00:00   4471
# 2024-01-13 14:02:00   3920
# 2024-01-13 14:04:00   2883
# 2024-01-13 14:06:00   9194
# 2024-01-13 14:08:00   3152
#
# [96 rows x 1 columns]

# %%
plt.plot(new_per5min_new['count'], marker='o')
plt.xlabel('Time (hour:minute)')
plt.ylabel('Count')
plt.title('first seen Count vs Time')
# Out:
# Text(0.5, 1.0, 'first seen Count vs Time')

# %%
df_last = df.drop_duplicates(subset='wlan.sa', keep='last')
df_last.tail()
# Out:
#           frame.number                                  frame.time  \
# 13870837        749927  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870838        749928  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870840        749930  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870842        749932  Jan  8, 2024 14:09 W. Europe Standard Time
# 13870843        749933  Jan  8, 2024 14:09 W. Europe Standard Time
#
#                     wlan.sa            wlan.da _ws.col.protocol  frame.len  \
# 13870837  00:f6:63:81:c8:6b  ff:ff:ff:ff:ff:ff           802.11        306
# 13870838  64:a2:00:49:ae:42  00:f6:63:81:c8:6f           802.11         45
# 13870840  aa:9f:59:02:dd:67  00:f6:63:81:c8:6f           802.11         43
# 13870842  00:f6:63:81:c8:6e  ff:ff:ff:ff:ff:ff           802.11        294
# 13870843                NaN                NaN           802.11         39
#
#           ip.src  ip.dst  _ws.col.Protocol  _ws.col.Info  \
# 13870837     NaN     NaN               NaN           NaN
# 13870838     NaN     NaN               NaN           NaN
# 13870840     NaN     NaN               NaN           NaN
# 13870842     NaN     NaN               NaN           NaN
# 13870843     NaN     NaN               NaN           NaN
#
#                          date-time hour:minute
# 13870837 2024-01-08 14:09:00+01:00       14:09
# 13870838 2024-01-08 14:09:00+01:00       14:09
# 13870840 2024-01-08 14:09:00+01:00       14:09
# 13870842 2024-01-08 14:09:00+01:00       14:09
# 13870843 2024-01-08 14:09:00+01:00       14:09

# %%
per_min_last=pd.DataFrame(df_last["hour:minute"].value_counts().sort_index())
plt.plot((per_min_last['count']/532), marker='o')
plt.xlabel('Time (hour:minute)')
plt.ylabel('Count')
plt.title('Last seen Count vs Time')
# Out:
# Text(0.5, 1.0, 'Last seen Count vs Time')

# %%
last_per5min = pd.DataFrame({'hour:minute':per_min_last.index.tolist(),'count': per_min_last["count"]})
last_per5min['hour:minute'] = pd.to_datetime(last_per5min['hour:minute'], format=None)
last_per5min.set_index('hour:minute', inplace=True)
last_per5min_new = last_per5min.resample('2T').sum()
last_per5min_new
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_25768\4113421914.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   last_per5min['hour:minute'] = pd.to_datetime(last_per5min['hour:minute'], format=None)
#                      count
# hour:minute
# 2024-01-13 10:58:00    467
# 2024-01-13 11:00:00    493
# 2024-01-13 11:02:00    171
# 2024-01-13 11:04:00    244
# 2024-01-13 11:06:00    136
# ...                    ...
# 2024-01-13 14:00:00   5481
# 2024-01-13 14:02:00   5080
# 2024-01-13 14:04:00   3414
# 2024-01-13 14:06:00  10763
# 2024-01-13 14:08:00   3373
#
# [96 rows x 1 columns]

# %%
plt.plot(last_per5min_new['count'], marker='o')
plt.xlabel('Time (hour:minute)')
plt.ylabel('Count')
plt.title('last seen Count vs Time')
# Out:
# Text(0.5, 1.0, 'last seen Count vs Time')

# %%
dtt = pd.DataFrame({'hour:minute':per_min.index.tolist(),'count': per_min["count"]})
dtt['hour:minute'] = pd.to_datetime(dtt['hour:minute'], format=None)
dtt.set_index('hour:minute', inplace=True)
dtt_new = dtt.resample('2T').sum()
dtt_new
plt.plot(dtt_new['count'], marker="o")
plt.xlabel('Time (hour:minute)')
plt.ylabel('Count')
plt.title('Count vs Time')
# Out:
# C:\Users\Sarthak\AppData\Local\Temp\ipykernel_19172\785444049.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dtt['hour:minute'] = pd.to_datetime(dtt['hour:minute'], format=None)
# Text(0.5, 1.0, 'Count vs Time')

# %%
ax=plt.plot_date(per_min.index,per_min["count"],xdate=True)

# %%
from dateutil import parser
from datetime import datetime
import re
